# %%
# Import packages and dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

GasUsage = pd.read_csv('GasUsage_complete.csv')
GasUsage
# Out:
#                              Date   Gas  Low  Average  High  SolarkWh  \
# 0          Tuesday, July 12, 2022  0.00   62    73.04    82    13.402
# 1           Monday, July 11, 2022  0.00   68    75.35    84     6.814
# 2           Sunday, July 10, 2022  0.00   60    71.17    80    13.158
# 3          Saturday, July 9, 2022  0.00   60    70.71    81    12.726
# 4            Friday, July 8, 2022  0.00   68    73.25    79     5.403
# ..                            ...   ...  ...      ...   ...       ...
# 513     Sunday, February 14, 2021  5.02   -3     3.08    10     0.013
# 514   Saturday, February 13, 2021  4.40   -9    -2.33     5     0.072
# 515     Friday, February 12, 2021  6.42   -7    -0.22     5     0.001
# 516   Thursday, February 11, 2021  6.22  -17    -8.62    -3     0.028
# 517  Wednesday, February 10, 2021  5.34  -11    -0.46     5     0.000
#
#      FireHrs  AwayHrs  PanelsFree  ConsumptionkWh  HotWaterkWh  Guests
# 0        0.0      0.0         1.0          19.950         1.41       0
# 1        0.0      0.0         1.0          18.095         0.66       0
# 2        0.0      0.0         1.0          16.851         1.00       0
# 3        0.0      0.0         1.0          16.039         1.41       0
# 4        0.0      0.0         1.0          17.935         0.95       0
# ..       ...      ...         ...             ...          ...     ...
# 513     10.0      0.0         0.0          19.419         0.91       0
# 514     13.0      0.0         0.0          17.665         1.33       0
# 515      0.0      0.0         0.0          18.687         0.89       0
# 516      0.0      0.0         0.0          22.315         1.28       0
# 517      0.0      2.0         0.0          18.317         1.48       0
#
# [518 rows x 12 columns]

# %%
# Convert date feature to YYYY-MM-DD
GasUsage['Date'] = pd.to_datetime(GasUsage['Date'])
GasUsage
# Out:
#           Date   Gas  Low  Average  High  SolarkWh  FireHrs  AwayHrs  \
# 0   2022-07-12  0.00   62    73.04    82    13.402      0.0      0.0
# 1   2022-07-11  0.00   68    75.35    84     6.814      0.0      0.0
# 2   2022-07-10  0.00   60    71.17    80    13.158      0.0      0.0
# 3   2022-07-09  0.00   60    70.71    81    12.726      0.0      0.0
# 4   2022-07-08  0.00   68    73.25    79     5.403      0.0      0.0
# ..         ...   ...  ...      ...   ...       ...      ...      ...
# 513 2021-02-14  5.02   -3     3.08    10     0.013     10.0      0.0
# 514 2021-02-13  4.40   -9    -2.33     5     0.072     13.0      0.0
# 515 2021-02-12  6.42   -7    -0.22     5     0.001      0.0      0.0
# 516 2021-02-11  6.22  -17    -8.62    -3     0.028      0.0      0.0
# 517 2021-02-10  5.34  -11    -0.46     5     0.000      0.0      2.0
#
#      PanelsFree  ConsumptionkWh  HotWaterkWh  Guests
# 0           1.0          19.950         1.41       0
# 1           1.0          18.095         0.66       0
# 2           1.0          16.851         1.00       0
# 3           1.0          16.039         1.41       0
# 4           1.0          17.935         0.95       0
# ..          ...             ...          ...     ...
# 513         0.0          19.419         0.91       0
# 514         0.0          17.665         1.33       0
# 515         0.0          18.687         0.89       0
# 516         0.0          22.315         1.28       0
# 517         0.0          18.317         1.48       0
#
# [518 rows x 12 columns]

# %%
# Time plot of gas usage by date
p1 = sns.lineplot(data=GasUsage, x='Date', y='Gas')
p1.set_xlabel('Date', fontsize=14);
p1.set_ylabel('Gas', fontsize=14);
plt.grid(axis='x');
plt.xticks(rotation=45);

# %%
# Scatterplot of gas usage by temperature
p2 = sns.scatterplot(data=GasUsage, x='Average', y='Gas')
p2.set_xlabel('Average temperature (F)', fontsize=14)
p2.set_ylabel('Gas', fontsize=14)
plt.grid()

# %%
# Combine plots in a single plotting window
# plt.subplot(rows, columns, plot index)
plt.rcParams["figure.figsize"] = (12, 5)

plt.subplot(1, 2, 1)
p1 = sns.lineplot(data=GasUsage, x='Date', y='Gas')
p1.set_xlabel('Date', fontsize=14)
p1.set_ylabel('Gas', fontsize=14)
plt.grid(axis='x')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
p2 = sns.scatterplot(data=GasUsage, x='Average', y='Gas')
p2.set_xlabel('Average temperature (F)', fontsize=14)
p2.set_ylabel('Gas', fontsize=14)
plt.grid()
